# %% [markdown]
# <a href="https://colab.research.google.com/github/Shankar-Hadimani/1000-dphi/blob/master/notebooks/1000_dphi_practice_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv')

# %%
x.head()
# Out:
#    land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0       1384          78.1            12.3  ...   72100       1       75.55
# 1       3719          43.9             9.4  ...   54542       2       56.03
# 2       3553          37.4            10.7  ...   33216       1       41.32
# 3       3916          29.9             8.8  ...   32906       2       67.38
# 4       2480          31.5            10.5  ...   26573       4       80.19
#
# [5 rows x 10 columns]

# %%
x.count()
# Out:
# land_area         99
# percent_city      99
# percent_senior    99
# physicians        99
# hospital_beds     99
# graduates         99
# work_force        99
# income            99
# region            99
# crime_rate        99
# dtype: int64

# %%
x.value_counts()
# Out:
# land_area  percent_city  percent_senior  physicians  hospital_beds  graduates  work_force  income  region  crime_rate
# 27293      25.3          12.3            2018        6323           57.4       510.6       7399    4       76.03         1
# 1404       38.5          10.0            299         1766           56.2       138.6       1776    2       40.54         1
# 1420       32.6          9.5             833         2950           54.0       280.8       3553    2       46.26         1
# 1456       46.7          10.4            2484        8555           56.8       710.4       10104   2       44.64         1
# 1465       30.3          6.8             598         6456           50.6       164.7       2201    3       70.66         1
#                                                                                                                         ..
# 2624       30.4          12.2            1532        4730           55.2       356.5       5094    1       38.75         1
# ...

# %%
x.describe()
# Out:
#           land_area  percent_city  ...     region  crime_rate
# count     99.000000     99.000000  ...  99.000000   99.000000
# mean    2615.727273     42.518182  ...   2.494949   55.643030
# std     3045.826210     17.348277  ...   1.013921   13.470943
# min       47.000000     13.400000  ...   1.000000   23.320000
# 25%     1408.000000     30.100000  ...   2.000000   46.115000
# 50%     1951.000000     39.500000  ...   3.000000   56.060000
# 75%     2890.500000     52.600000  ...   3.000000   63.860000
# max    27293.000000    100.000000  ...   4.000000   85.620000
#
# [8 rows x 10 columns]

# %%
plt.scatter(x.percent_senior, x.crime_rate)
plt.title('Plot of crime Rate Vs Percent Seniors')
plt.xlabel('Percent Senior')
plt.ylabel('Crime Rate')
plt.show()

# %%
plt.plot([1,2,3,4,5])
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income)
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, linestyle='--', marker='o', color='r')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, '--ro')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'ro')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, '-b')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
plt.plot(x.work_force, x.income, "gx") # gx = green x
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'go')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'g^')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'rx')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'bx')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'b^')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
## set fig size
plt.figure(figsize=(12,5))
plt.plot(x.work_force, x.income, 'go--')
plt.xlabel('Work Force')
plt.ylabel('Income')
plt.show()

# %%
plt.plot(x.work_force, x.income, color='r')
plt.show()

plt.plot(x.physicians, x.income)
plt.show()

# %%
plt.plot(x.work_force, x.income, color='r')

plt.plot(x.physicians, x.income)

# adding legends 
plt.legend()
## show
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(x.work_force, x.income, color='r', label='work force income')

plt.plot(x.physicians, x.income, label='physicians income')

# adding legends 
plt.legend()
## show
plt.show()

# %%
# multiple plots

# %%
plt.subplot(1, 2, 1) ## rows, columns, index
plt.plot(x.work_force, x.income, 'go')
plt.title('Income Vs Work force')


## plt.subplot(1, 2, 2) # rows, column , index
plt.subplot(1, 2, 2).label_outer()

plt.plot(x.hospital_beds, x.income, 'r^')
plt.title('Income Vs Hosiptal Beds')

plt.suptitle('Sub Plots')
plt.show()

# %%
plt.subplot(2, 1, 1)  # row, column, index
plt.plot(x.work_force, x.income, 'bo')
plt.title('Income Vs workForce')

plt.subplot(2,1,2) 
plt.plot(x.hospital_beds, x.income, 'r^')

plt.suptitle('Sub Plots')
plt.show()

# %%
### 2 rows and 2 columns 

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6)) ### 2 rows, 2 columns and figuresize
ax[0,0].plot(x.work_force, x.income, 'go')  # top-left axes
ax[0,1].plot(x.work_force, x.income, 'bo')  # top-right axes
ax[1,0].plot(x.work_force, x.income, 'yo')  # bottom-left axes
ax[1,1].plot(x.work_force, x.income, 'ro') #  bottom-right axes
plt.show()

# %%
### histograms
### A histogram shows the frequency on the vertical axis and the horizontal axis is another dimension.
###Usually it has bins, where every bin has a minimum and maximum value. Each bin also has a frequency between x and infinite

# %%
print(x.percent_senior.min())
print(x.percent_senior.max())
print(x.percent_senior.mean())
print(x.percent_senior.median())
# Out:
# 3.9
# 21.8
# 9.781818181818185
# 9.7

# %%
plt.title('Histogram')
plt.xlabel('Percenttage of Senior Citizens')
plt.ylabel('Frequency')

plt.hist(x.percent_senior)
plt.show()

# %% [markdown]
# # **Seaborn**

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 126           6.2          2.8           4.8          1.8   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 40            5.0          3.5           1.3          0.3      setosa
# 47            4.6          3.2           1.4          0.2      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 135           7.7          3.0           6.1          2.3   virginica
# 18            5.7          3.8           1.7          0.3      setosa
# 129           7.2          3.0           5.8          1.6   virginica
# 3             4.6          3.1           1.5          0.2      setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# scatter plot using  Seabon

# %%
sns.swarmplot(x='species', y = 'petal_length', data=iris)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='sepal_length', y='sepal_width', data=iris)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # **Heatmap using Seaborn**  ***for correlation matrix visualization***
#
# ---
# Correlation is a measure of the strength of a linear relationship between two quantitative variables.

# %%
# co-relation matrix completely ignores any non-numeric columns.
sns.heatmap(iris.corr(), annot=True)
plt.show()

# %% [markdown]
# **Bar Chart using Matplotlib**

# %%
plt.bar(x.region, x.crime_rate, color='blue')
plt.xlabel('Region')
plt.ylabel('Crime rate')
plt.title('Crime rate Vs region')
plt.show()

# %%
plt.barh(x.region, x.crime_rate, color='green')
plt.title('Crime Vs region horizontal Bar Graph')
plt.show()

# %%
class_divisions = ['A','B','C','D','E']
class_divisions_avg = [70,82,73,65,68]
boys_avg = [68, 67, 77, 61, 70]

# Using the NumPy arange function to generate values for index between 0-4.
# Here,stop is 5, start is 0, and step is 1
index = np.arange(5)
index_width = 0.30

plt.bar(index, class_divisions_avg, color ='red', label='Class Division Avg Marks')
plt.bar(index+index_width, boys_avg, index_width, color='blue', label='Boys Marks' )
#plt.bar(x=index+index_width, height=boys_avg, width=index_width,color='blue', label='Boys Marks' )   

plt.title('Bar Graph')
plt.xlabel('Divisions')
plt.ylabel('Mars')
plt.show()

# %%
divisions = ["A", "B", "C", "D", "E"]
girls_avg = [72, 97, 69, 69, 66]
boys_avg = [68, 67, 77, 61, 70]

index = np.arange(5)
width = 0.50

plt.bar(index, boys_avg, width, color="green", label="Boys Marks")
plt.bar(index, girls_avg, width, color="blue", label="Girls Marks", bottom=boys_avg)

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.show()

# %%
divisions = ["A", "B", "C", "D", "E"]
division_avg = [70, 82, 73, 65, 68]
boys_avg = [68, 67, 77, 61, 70]

# Using the NumPy arange function to generate values for index between 0-4.
# Here,stop is 5, start is 0, and step is 1
index = np.arange(5) 
width = 0.30

plt.bar(index, division_avg, width, color="green", label="Division Marks")
plt.bar(index+width, boys_avg, width, color="blue", label="Boys Marks")

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.show()

# %%
firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_share = [20,25,15,10,20]

# Explode the pie chart to emphasize a certain part or some parts( Firm B in this case) 
# It is useful because it makes the highlighted portion more visible.
Explode = [0,0.1,0,0,0] 

plt.pie(market_share, explode=Explode, labels=firms, autopct='%1.1f%%', startangle=45)

plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend(title="List of Firms")

plt.show()

# %%
firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_share = [20,25,15,10,20]
Explode = [0,1,1,0, 0] 
plt.pie(x=market_share, explode=Explode, labels=firms, autopct='%1.1f%%', startangle=45)
plt.show()
